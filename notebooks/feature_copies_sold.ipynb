# %%
import pandas as pd

# %%
merged_platform_df = pd.read_pickle("../data/interim/merged_platform_data.pkl")

# %%
merged_platform_df

# %%
merged_platform_df["release_year"] = pd.to_datetime(merged_platform_df["release"]).dt.year

# %%
def estimate_copies_sold(row):
    year = row["release_year"]
    reviews = row["user_reviews"]

    if year < 2013:
        multiple = 120
    elif 2013 <= year < 2017:
        multiple = 85
    elif 2017 <= year < 2019:
        multiple = 70
    else:  # 2019 and later
        multiple = 30

    return reviews * multiple

merged_platform_df["reviews_sold_copies_proxy"] = merged_platform_df.apply(estimate_copies_sold, axis=1)
