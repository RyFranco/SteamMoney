# %%
import pandas as pd

# %%
df_sentiment = pd.read_pickle("../data/processed/app_level_sentiment.pkl")

# %%
main_df = pd.read_pickle("../data/interim/merged_data.pkl")

# %%
df_sentiment
# Out:
#       app_id  avg_sentiment  num_reviews                   app_name  \
# 0         10       0.676647        11155             Counter-Strike
# 1         20       0.445040         1492      Team Fortress Classic
# 2         30       0.508577          991              Day of Defeat
# 3         40       0.405830          446         Deathmatch Classic
# 4         50       0.419870         1691  Half-Life: Opposing Force
# ...      ...            ...          ...                        ...
# 9956  562220       0.535461          282                     Zup! 2
# 9959  562320       0.250000           12               Locked In VR
# 9961  562700       0.400000           10              Paintball 707
# 9965  563400       0.400000           10                       Ludu
# 9966  563430       0.444444           18               Void Pyramid
#
#       percent_positive
# 0            67.664724
# 1            44.504021
# 2            50.857719
# 3            40.582960
# 4            41.986990
# ...                ...
# 9956         53.546099
# 9959         25.000000
# 9961         40.000000
# 9965         40.000000
# 9966         44.444444
#
# [8593 rows x 5 columns]

# %%
merged_df = main_df.merge(df_sentiment[["app_id", "avg_sentiment"]], on="app_id", how="left")

# %%
merged_df
# Out:
#         app_id     release  peak_players                               title  \
# 0      2231450  2023-01-26          4529                         Pizza Tower
# 1      2050650  2023-03-24        168191                     Resident Evil 4
# 2      2324650  2023-03-31         15543    The Murder of Sonic the Hedgehog
# 3      2263010  2023-03-28          1415                  Pineapple on pizza
# 4      1817230  2023-01-25          6132                          Hi-Fi RUSH
# ...        ...         ...           ...                                 ...
# 37486     1690  2006-10-16           137                     Space Empires V
# 37487     1670  2006-07-26            15  Iron Warriors: T - 72 Tank Command
# 37488     2520  2006-12-19            22          Gumboy - Crazy Adventures™
# 37489     3960  2006-10-25            13                     Shattered Union
# 37490     4100  2006-10-05             9                 Poker Superstars II
#
#         win    mac  linux  user_reviews  \
# 0      True  False  False         35131
# 1      True  False  False         55455
# 2      True   True  False         13564
# 3      True   True   True         12588
# 4      True  False  False         16025
# ...     ...    ...    ...           ...
# 37486  True  False  False           360
# 37487  True  False  False           250
# 37488  True  False  False            98
# 37489  True  False  False           126
# 37490  True  False  False            13
#
#                                               Categories  \
# 0      Single-player,Multi-player,Co-op,Shared/Split ...
# 1      Single-player,Steam Achievements,Full controll...
# 2                                          Single-player
# 3      Single-player,Steam Achievements,Full controll...
# 4      Single-player,Steam Achievements,Full controll...
# ...                                                  ...
# 37486          Single-player,Multi-player,Family Sharing
# 37487          Single-player,Multi-player,Family Sharing
# 37488                       Single-player,Family Sharing
# 37489          Single-player,Multi-player,Family Sharing
# 37490                       Single-player,Family Sharing
#
#                                      Genres                          Tags  \
# 0                              Action,Indie                           NaN
# 1                          Action,Adventure                           NaN
# 2      Casual,Free To Play,Indie,Simulation                           NaN
# 3                 Casual,Indie,Free To Play                           NaN
# 4                                    Action                           NaN
# ...                                     ...                           ...
# 37486                              Strategy                           NaN
# 37487                              Strategy                           NaN
# 37488                          Casual,Indie                           NaN
# 37489                              Strategy  Strategy,Turn-Based Strategy
# 37490                 Casual,Strategy,Indie                           NaN
#
#        Price  avg_sentiment
# 0      19.99            NaN
# 1      39.99            NaN
# 2       0.00            NaN
# 3       0.00            NaN
# 4      29.99            NaN
# ...      ...            ...
# 37486   2.99       0.242236
# 37487   1.19            NaN
# 37488   4.99       0.269231
# 37489   4.99       0.169231
# 37490   9.99            NaN
#
# [37491 rows x 13 columns]

# %%
merged_df['avg_sentiment'].isna().value_counts()
# Out:
# avg_sentiment
# True     30631
# False     6860
# Name: count, dtype: int64

# %%
merged_df['has_sentiment'] = merged_df['avg_sentiment'].notna().astype(int)

# %%
df_main = pd.read_pickle("../data/interim/merged_data.pkl")

# %%
df_main
# Out:
#         app_id     release  peak_players                               title  \
# 0      2231450  2023-01-26          4529                         Pizza Tower
# 1      2050650  2023-03-24        168191                     Resident Evil 4
# 2      2324650  2023-03-31         15543    The Murder of Sonic the Hedgehog
# 3      2263010  2023-03-28          1415                  Pineapple on pizza
# 4      1817230  2023-01-25          6132                          Hi-Fi RUSH
# ...        ...         ...           ...                                 ...
# 37486     1690  2006-10-16           137                     Space Empires V
# 37487     1670  2006-07-26            15  Iron Warriors: T - 72 Tank Command
# 37488     2520  2006-12-19            22          Gumboy - Crazy Adventures™
# 37489     3960  2006-10-25            13                     Shattered Union
# 37490     4100  2006-10-05             9                 Poker Superstars II
#
#         win    mac  linux  user_reviews  \
# 0      True  False  False         35131
# 1      True  False  False         55455
# 2      True   True  False         13564
# 3      True   True   True         12588
# 4      True  False  False         16025
# ...     ...    ...    ...           ...
# 37486  True  False  False           360
# 37487  True  False  False           250
# 37488  True  False  False            98
# 37489  True  False  False           126
# 37490  True  False  False            13
#
#                                               Categories  \
# 0      Single-player,Multi-player,Co-op,Shared/Split ...
# 1      Single-player,Steam Achievements,Full controll...
# 2                                          Single-player
# 3      Single-player,Steam Achievements,Full controll...
# 4      Single-player,Steam Achievements,Full controll...
# ...                                                  ...
# 37486          Single-player,Multi-player,Family Sharing
# 37487          Single-player,Multi-player,Family Sharing
# 37488                       Single-player,Family Sharing
# 37489          Single-player,Multi-player,Family Sharing
# 37490                       Single-player,Family Sharing
#
#                                      Genres                          Tags  \
# 0                              Action,Indie                           NaN
# 1                          Action,Adventure                           NaN
# 2      Casual,Free To Play,Indie,Simulation                           NaN
# 3                 Casual,Indie,Free To Play                           NaN
# 4                                    Action                           NaN
# ...                                     ...                           ...
# 37486                              Strategy                           NaN
# 37487                              Strategy                           NaN
# 37488                          Casual,Indie                           NaN
# 37489                              Strategy  Strategy,Turn-Based Strategy
# 37490                 Casual,Strategy,Indie                           NaN
#
#        Price  avg_sentiment  has_sentiment
# 0      19.99            NaN              0
# 1      39.99            NaN              0
# 2       0.00            NaN              0
# 3       0.00            NaN              0
# 4      29.99            NaN              0
# ...      ...            ...            ...
# 37486   2.99       0.242236              1
# 37487   1.19            NaN              0
# 37488   4.99       0.269231              1
# 37489   4.99       0.169231              1
# 37490   9.99            NaN              0
#
# [37491 rows x 14 columns]
